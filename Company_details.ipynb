# %%
import numpy as np
import pandas as pd

# %%
Data = pd.read_csv("company_details.csv")
Data
# Out:
#     R&D Spend  Administration  Marketing Spend       State        Profit
# 0   165349.20     136897.8000      471784.1000    New York  192261.83000
# 1   162597.70     151377.5900      443898.5300  California  191792.06000
# 2   153441.51     101145.5500      407934.5400     Florida  191050.39000
# 3   144372.41     118671.8500      383199.6200    New York  182901.99000
# 4   142107.34      91391.7700      366168.4200     Florida  166187.94000
# ..        ...             ...              ...         ...           ...
# 94  125158.00     128940.9992      310271.7420  California  155954.29850
# 95  138570.00     130921.7444      336150.2326    New York  167412.05440
# 96   46445.00     117316.3048      158394.7935     Florida   88710.46186
# 97  134739.00     130355.9649      328758.3076  California  164139.26420
# 98   96620.00     124726.3773      255207.5930    New York  131574.53140
#
# [99 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
Label = LabelEncoder()
Data.iloc[:,3] = Label.fit_transform(Data.iloc[:,3])
Data
# Out:
#     R&D Spend  Administration  Marketing Spend  State        Profit
# 0   165349.20     136897.8000      471784.1000      2  192261.83000
# 1   162597.70     151377.5900      443898.5300      0  191792.06000
# 2   153441.51     101145.5500      407934.5400      1  191050.39000
# 3   144372.41     118671.8500      383199.6200      2  182901.99000
# 4   142107.34      91391.7700      366168.4200      1  166187.94000
# ..        ...             ...              ...    ...           ...
# 94  125158.00     128940.9992      310271.7420      0  155954.29850
# 95  138570.00     130921.7444      336150.2326      2  167412.05440
# 96   46445.00     117316.3048      158394.7935      1   88710.46186
# 97  134739.00     130355.9649      328758.3076      0  164139.26420
# 98   96620.00     124726.3773      255207.5930      2  131574.53140
#
# [99 rows x 5 columns]

# %%
Data1 = pd.get_dummies(Data.iloc[:,3])
Data1
# Out:
#     0  1  2
# 0   0  0  1
# 1   1  0  0
# 2   0  1  0
# 3   0  0  1
# 4   0  1  0
# .. .. .. ..
# 94  1  0  0
# 95  0  0  1
# 96  0  1  0
# 97  1  0  0
# 98  0  0  1
#
# [99 rows x 3 columns]

# %%
Data2 = pd.concat([Data,Data1],axis = 1)
Data2
# Out:
#     R&D Spend  Administration  Marketing Spend  State        Profit  0  1  2
# 0   165349.20     136897.8000      471784.1000      2  192261.83000  0  0  1
# 1   162597.70     151377.5900      443898.5300      0  191792.06000  1  0  0
# 2   153441.51     101145.5500      407934.5400      1  191050.39000  0  1  0
# 3   144372.41     118671.8500      383199.6200      2  182901.99000  0  0  1
# 4   142107.34      91391.7700      366168.4200      1  166187.94000  0  1  0
# ..        ...             ...              ...    ...           ... .. .. ..
# 94  125158.00     128940.9992      310271.7420      0  155954.29850  1  0  0
# 95  138570.00     130921.7444      336150.2326      2  167412.05440  0  0  1
# 96   46445.00     117316.3048      158394.7935      1   88710.46186  0  1  0
# 97  134739.00     130355.9649      328758.3076      0  164139.26420  1  0  0
# 98   96620.00     124726.3773      255207.5930      2  131574.53140  0  0  1
#
# [99 rows x 8 columns]

# %%
Data2.iloc[:,[0,1,2,5,6,7]]
# Out:
#     R&D Spend  Administration  Marketing Spend  0  1  2
# 0   165349.20     136897.8000      471784.1000  0  0  1
# 1   162597.70     151377.5900      443898.5300  1  0  0
# 2   153441.51     101145.5500      407934.5400  0  1  0
# 3   144372.41     118671.8500      383199.6200  0  0  1
# 4   142107.34      91391.7700      366168.4200  0  1  0
# ..        ...             ...              ... .. .. ..
# 94  125158.00     128940.9992      310271.7420  1  0  0
# 95  138570.00     130921.7444      336150.2326  0  0  1
# 96   46445.00     117316.3048      158394.7935  0  1  0
# 97  134739.00     130355.9649      328758.3076  1  0  0
# 98   96620.00     124726.3773      255207.5930  0  0  1
#
# [99 rows x 6 columns]

# %%
Data2.iloc[:,[0,1,2,5,6,7,4]]
# Out:
#     R&D Spend  Administration  Marketing Spend  0  1  2        Profit
# 0   165349.20     136897.8000      471784.1000  0  0  1  192261.83000
# 1   162597.70     151377.5900      443898.5300  1  0  0  191792.06000
# 2   153441.51     101145.5500      407934.5400  0  1  0  191050.39000
# 3   144372.41     118671.8500      383199.6200  0  0  1  182901.99000
# 4   142107.34      91391.7700      366168.4200  0  1  0  166187.94000
# ..        ...             ...              ... .. .. ..           ...
# 94  125158.00     128940.9992      310271.7420  1  0  0  155954.29850
# 95  138570.00     130921.7444      336150.2326  0  0  1  167412.05440
# 96   46445.00     117316.3048      158394.7935  0  1  0   88710.46186
# 97  134739.00     130355.9649      328758.3076  1  0  0  164139.26420
# 98   96620.00     124726.3773      255207.5930  0  0  1  131574.53140
#
# [99 rows x 7 columns]

# %%
Data2.iloc[:,[0,1,2,5,6,4]]
# Out:
#     R&D Spend  Administration  Marketing Spend  0  1        Profit
# 0   165349.20     136897.8000      471784.1000  0  0  192261.83000
# 1   162597.70     151377.5900      443898.5300  1  0  191792.06000
# 2   153441.51     101145.5500      407934.5400  0  1  191050.39000
# 3   144372.41     118671.8500      383199.6200  0  0  182901.99000
# 4   142107.34      91391.7700      366168.4200  0  1  166187.94000
# ..        ...             ...              ... .. ..           ...
# 94  125158.00     128940.9992      310271.7420  1  0  155954.29850
# 95  138570.00     130921.7444      336150.2326  0  0  167412.05440
# 96   46445.00     117316.3048      158394.7935  0  1   88710.46186
# 97  134739.00     130355.9649      328758.3076  1  0  164139.26420
# 98   96620.00     124726.3773      255207.5930  0  0  131574.53140
#
# [99 rows x 6 columns]

# %%
x = Data2.iloc[:,[0,1,2]].values
x
# Out:
# array([[165349.2    , 136897.8    , 471784.1    ],
#        [162597.7    , 151377.59   , 443898.53   ],
#        [153441.51   , 101145.55   , 407934.54   ],
#        [144372.41   , 118671.85   , 383199.62   ],
#        [142107.34   ,  91391.77   , 366168.42   ],
#        [131876.9    ,  99814.71   , 362861.36   ],
#        [134615.46   , 147198.87   , 127716.82   ],
#        [130298.13   , 145530.06   , 323876.68   ],
#        [120542.52   , 148718.95   , 311613.29   ],
#        [123334.88   , 108679.17   , 304981.62   ],
#        [101913.08   , 110594.11   , 229160.95   ],
#        [100671.96   ,  91790.61   , 249744.55   ],
#        [ 93863.75   , 127320.38   , 249839.44   ],
#        [ 91992.39   , 135495.07   , 252664.93   ],
#        [119943.24   , 156547.42   , 256512.92   ],
#        [114523.61   , 122616.84   , 261776.23   ],
#        [ 78013.11   , 121597.55   , 264346.06   ],
#        [ 94657.16   , 145077.58   , 282574.31   ],
# ...

# %%
y = Data.iloc[:,[-1]].values
y
# Out:
# array([[192261.83   ],
#        [191792.06   ],
#        [191050.39   ],
#        [182901.99   ],
#        [166187.94   ],
#        [156991.12   ],
#        [156122.51   ],
#        [155752.6    ],
#        [152211.77   ],
#        [149759.96   ],
#        [146121.95   ],
#        [144259.4    ],
#        [141585.52   ],
#        [134307.35   ],
#        [132602.65   ],
#        [129917.04   ],
#        [126992.93   ],
#        [125370.37   ],
#        [124266.9    ],
#        [122776.86   ],
#        [118474.03   ],
#        [111313.02   ],
#        [110352.25   ],
#        [108733.99   ],
#        [108552.04   ],
#        [107404.34   ],
#        [105733.54   ],
#        [105008.31   ],
#        [103282.38   ],
#        [101004.64   ],
#        [ 99937.59   ],
#        [ 97483.56   ],
#        [ 97427.84   ],
#        [ 96778.92   ],
#        [ 96712.8    ],
#        [ 96479.51   ],
#        [ 90708.19   ],
#        [ 89949.14   ],
#        [ 81229.06   ],
#        [ 81005.76   ],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[167661.30137522],
#        [191879.74442658],
#        [139644.6879046 ],
#        [ 89451.81682007],
#        [176852.03968965],
#        [ 82310.49274534],
#        [ 70633.94264274],
#        [188476.63145738],
#        [181364.12701896],
#        [114351.9472133 ],
#        [165814.16397367],
#        [116527.71957256],
#        [ 98768.73581681],
#        [ 56800.82976281],
#        [154144.4828089 ],
#        [121867.89859319],
#        [155246.97753881],
#        [102668.01627461],
#        [115563.20646266],
#        [128630.29942295]])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9884903354492445
